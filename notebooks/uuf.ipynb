# %%
import sys
sys.path.append('..')
from  src.uuf import ask_question
# Out:
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /sentence-transformers/all-MiniLM-L6-v2/resolve/main/modules.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: ccefb638-1559-448c-8186-26fc28e71af2)')' thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./modules.json
# Retrying in 1s [Retry 1/5].
# ...

# %%
questions = [
    "Why are people unhappy with credit cards?",
    "What are common complaints about money transfers?",
]

for q in questions:
    print("QUESTION:", q)
    result = ask_question(q)
    print("\nANSWER:\n", result["answer"][:800])
# Out:
# QUESTION: Why are people unhappy with credit cards?
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /google/flan-t5-large/resolve/main/config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: 15c91bb6-c862-424d-9064-e1af0a1ec744)')' thrown while requesting HEAD https://huggingface.co/google/flan-t5-large/resolve/main/config.json
# Retrying in 1s [Retry 1/5].
# ...

# %%
result = ask_question("Why are customers unhappy with credit cards?")

print("\n--- SOURCES USED ---\n")
for i, src in enumerate(result["sources"], 1):
    print(f"[Source {i}]")
    print(src["text"][:500])
    print()
# Out:
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /google/flan-t5-large/resolve/main/config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: 7514ad0f-d03c-4480-a765-e9f7afbb4af2)')' thrown while requesting HEAD https://huggingface.co/google/flan-t5-large/resolve/main/config.json
# Retrying in 1s [Retry 1/5].
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /google/flan-t5-large/resolve/main/config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: abcfb505-d4e7-4406-9dc4-eb398fe6e448)')' thrown while requesting HEAD https://huggingface.co/google/flan-t5-large/resolve/main/config.json
# Retrying in 2s [Retry 2/5].
# ...
