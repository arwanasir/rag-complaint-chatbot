# %%
import sys
sys.path.append('..')
import pandas as pd
from src.task2 import (stratified_sample,text_split,embed_and_index)
# Out:
# c:\Users\arwa\rag-complaint-chatbot\venv\Lib\site-packages\langchain_core\_api\deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
df_cleaned = pd.read_csv("../data/processed/cleaned_complaints.csv")

# %%
df_cleaned.head()
# Out:
#   Date received                                            Product  \
# 0    2025-06-11                              Vehicle loan or lease
# 1    2025-06-07                              Vehicle loan or lease
# 2    2025-06-09  Money transfer, virtual currency, or money ser...
# 3    2025-06-07  Money transfer, virtual currency, or money ser...
# 4    2025-05-15  Money transfer, virtual currency, or money ser...
#
#                 Sub-product  \
# 0                      Loan
# 1                      Loan
# 2  Mobile or digital wallet
# 3  Mobile or digital wallet
# 4  Mobile or digital wallet
#
#                                                Issue  \
# 0                                       Repossession
# 1                            Getting a loan or lease
# 2                                      Fraud or scam
# 3  Unauthorized transactions or other transaction...
# 4  Managing, opening, or closing your mobile wall...
#
#                                           Sub-issue  \
# ...

# %%
df_samples = stratified_sample(df_cleaned)
# Out:
# sample created with 15000 rows

# %%
print("Original Proportions:")
print(df_cleaned['Product'].value_counts(normalize=True))

print("\nSample Proportions:")
print(df_samples['Product'].value_counts(normalize=True))
# Out:
# Original Proportions:
# Product
# Credit card or prepaid card                           0.442758
# Money transfer, virtual currency, or money service    0.395987
# Vehicle loan or lease                                 0.161254
# Name: proportion, dtype: float64
#
# Sample Proportions:
# Product
# Credit card or prepaid card                           0.442733
# Money transfer, virtual currency, or money service    0.396000
# Vehicle loan or lease                                 0.161267
# Name: proportion, dtype: float64

# %%
df_samples.head()
# Out:
#        Date received                                            Product  \
# 193617    2021-12-19                              Vehicle loan or lease
# 106985    2019-05-20  Money transfer, virtual currency, or money ser...
# 205558    2019-04-23                        Credit card or prepaid card
# 175571    2017-08-07                        Credit card or prepaid card
# 181981    2022-08-15  Money transfer, virtual currency, or money ser...
#
#                                        Sub-product  \
# 193617                                        Loan
# 106985                Domestic (US) money transfer
# 205558  General-purpose credit card or charge card
# 175571  General-purpose credit card or charge card
# 181981                Domestic (US) money transfer
#
#                                                     Issue  \
# 193617                        Struggling to pay your loan
# 106985                                      Fraud or scam
# ...

# %%
df_chunks = text_split(df_samples)
# Out:
# Original narratives: 15000
# Total chunks created: 41865
#                                                chunk  \
# 0  veros credit harasses me for only being a few ...
# 1  calling and harassing our references yes i agr...
# 2  i had 10 unauthorized transfers out of my chas...
# 3  signed up for nor of any of the transactions a...
# 4  in this information and their fraud department...
#
#                                              Product  complaint_id
# 0                              Vehicle loan or lease        193617
# 1                              Vehicle loan or lease        193617
# 2  Money transfer, virtual currency, or money ser...        106985
# 3  Money transfer, virtual currency, or money ser...        106985
# 4  Money transfer, virtual currency, or money ser...        106985

# %%
print(f"The data type is: {type(df_chunks)}")
# Out:
# The data type is: <class 'pandas.core.frame.DataFrame'>

# %%
df_chunks = pd.DataFrame(df_chunks)

# %%
x = embed_and_index(df_chunks)
print(x)
# Out:
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: 7b462db9-9c9b-4c8b-9410-690fd4a38ece)')' thrown while requesting HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/config_sentence_transformers.json
# Retrying in 1s [Retry 1/5].
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: 0626d4e9-ae06-4866-80be-83c9c1d66ffe)')' thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./README.md
# Retrying in 1s [Retry 1/5].
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: 9dc61d8a-e0a5-4f13-89bd-d73e84af6515)')' thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/tokenizer_config.json
# ...

# %%
df_chunks.to_csv('../data/processed/df_chunks.csv')

# %%
df_cleaned['cleaned_narratives'].isnull().sum()
# Out:
# np.int64(3)

# %%
df_cleaned['Product'].nunique()
# Out:
# 3

# %%
df_cleaned.head(10)
# Out:
#   Date received                                            Product  \
# 0    2025-06-11                              Vehicle loan or lease
# 1    2025-06-07                              Vehicle loan or lease
# 2    2025-06-09  Money transfer, virtual currency, or money ser...
# 3    2025-06-07  Money transfer, virtual currency, or money ser...
# 4    2025-05-15  Money transfer, virtual currency, or money ser...
# 5    2025-05-28                              Vehicle loan or lease
# 6    2025-03-17  Money transfer, virtual currency, or money ser...
# 7    2025-05-01  Money transfer, virtual currency, or money ser...
# 8    2025-05-24                              Vehicle loan or lease
# 9    2025-06-05                              Vehicle loan or lease
#
#                     Sub-product  \
# 0                          Loan
# 1                          Loan
# 2      Mobile or digital wallet
# 3      Mobile or digital wallet
# 4      Mobile or digital wallet
# ...
