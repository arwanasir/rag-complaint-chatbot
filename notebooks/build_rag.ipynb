# %%
import pandas as pd
import sys
sys.path.append('..')
from src.build_rag import(load_resources,get_llm_pipeline,ask_assistant)

# %%
vectors_path = "../vector_stores/complaints_index.faiss"
pkls_path = "../vector_stores/metadata.pkl"

# %%
df_chunks,index,embed_model = load_resources(vectors_path,pkls_path)

# %%
df_chunks.head()
# Out:
#                                                chunk  \
# 0  veros credit harasses me for only being a few ...
# 1  calling and harassing our references yes i agr...
# 2  i had 10 unauthorized transfers out of my chas...
# 3  signed up for nor of any of the transactions a...
# 4  in this information and their fraud department...
#
#                                              Product  complaint_id
# 0                              Vehicle loan or lease        193617
# 1                              Vehicle loan or lease        193617
# 2  Money transfer, virtual currency, or money ser...        106985
# 3  Money transfer, virtual currency, or money ser...        106985
# 4  Money transfer, virtual currency, or money ser...        106985

# %%
generator =get_llm_pipeline()
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# Device set to use cpu

# %%
test_questions = ["What are common themes in identity theft complaints?",
                  "How do people describe hidden fees in credit cards?",
                  "What are the common complaints about credit reporting?",
                  "What are common issues with debt collection?",
                "Who is the current CEO of the largest bank in this dataset?",
                "What is the best way to invest in the stock market according to these complaints?"
]

# %%
for q in test_questions:
    print(f"\nquestion:{q}")
    print(f"\nchatbot:{ask_assistant(q,df_chunks,index,embed_model,generator)}")
# Out:
# question:What are common themes in identity theft complaints?
# Both `max_new_tokens` (=256) and `max_length`(=150) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# chatbot:the corona virus pandemic
#
# question:How do people describe hidden fees in credit cards?
# Both `max_new_tokens` (=256) and `max_length`(=150) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# chatbot:I don't have enough information based on the records.
#
# question:What are the common complaints about credit reporting?
# Both `max_new_tokens` (=256) and `max_length`(=150) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# chatbot:not responsible for and to fix the credit reports they have marked negatively since i see no issues on my credit report i have no other idea but that it is associated directly to my having a heavy accent and being elderly i called my creditor and bank to see if they had received a call fro m paypal to co nfirm my statement information which was requested and they had not so a proper investigation has not been made and i ve been unfairly judged and discriminated against the credit reporting i think it is unfair and illegal to negatively impact customers consumer reports during a global pandemic especially when i wasnt contacted about the status of the account
#
# question:What are common issues with debt collection?
# Both `max_new_tokens` (=256) and `max_length`(=150) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# chatbot:not providing adequate information to be able to evaluate a debt due is in violation of the fair debt collections practices act specifically validation of debts under notice of debts 809 a 4 debt has been high throughout that time period as well the debt and push it to collection agencies
#
# question:Who is the current CEO of the largest bank in this dataset?
# Both `max_new_tokens` (=256) and `max_length`(=150) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# chatbot:I don't have enough information.
#
# question:What is the best way to invest in the stock market according to these complaints?
# Both `max_new_tokens` (=256) and `max_length`(=150) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# chatbot:I don't have enough information.

# %%
print(f"\nchatbot:{ask_assistant("how to bake a cake?",df_chunks,index,embed_model,generator)}")

# %%
print(f"\nchatbot:{ask_assistant("what is my name?",df_chunks,index,embed_model,generator)}")

# %%
print(f"\nchatbot:{ask_assistant("whats the steps to bake a pancake?",df_chunks,index,embed_model,generator)}")

# %%
print(f"\nchatbot:{ask_assistant("What are the common complaints about credit reporting?",df_chunks,index,embed_model,generator)}")

# %%
# 1. Ask the question
query = "How to bake a cake?"

# 2. Get the "Docs" from your FAISS files
docs = vectors_path.similarity_search(query, k=3)

# 3. THE FIX: Print the source text
print("\n--- WHAT THE DATABASE FOUND ---")
if len(docs) == 0:
    print("Empty! The search found nothing in your files.")
else:
    for i, doc in enumerate(docs):
        print(f"Source {i+1} snippet: {doc.page_content[:200]}...") 
print("-------------------------------\n")

# 4. Now run your generation code as usual
